# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
image = Image.open("Source/minna.jpg")
image.show()      # this opens default image viewer in your current operating system

# %%
plt.imshow(image.rotate(180))

# %%
image.rotate(180).save("Source/test.jpg")

# %%
image2 = Image.open("Source/test.jpg")
img2_channels = image2.copy()
r, g, b = img2_channels.split()
img_bgr = Image.merge("RGB", (b, g, r))


plt.imshow(img_bgr)

# %%
img_gbr = Image.merge("RGB", (g, b, r))
plt.imshow(img_gbr)

# %%
img_grb = Image.merge("RGB", (g, r, b))
plt.imshow(img_grb)

# %%
img_brg = Image.merge("RGB", (b, r, g))
plt.imshow(img_brg)

# %%
img_bgr = Image.merge("RGB", (r, b, g))
plt.imshow(img_bgr)
